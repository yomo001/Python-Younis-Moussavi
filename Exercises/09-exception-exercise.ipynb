# %% [markdown]
# <a href="https://colab.research.google.com/github/kokchun/Python-course-AI22/blob/main/Exercises/07-exception-exercise.ipynb" target="_parent"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a> &nbsp; to see hints and answers.

# %% [markdown]
# # Error handling exercises
#
# ---
# These are introductory exercises in Python with focus in **error handling** statement.
#
# <p class = "alert alert-info" role="alert"><b>Remember</b> to use <b>descriptive variable and function names</b> in order to get readable code </p>
#
# <p class = "alert alert-info" role="alert"><b>Remember</b> to format your answers in a neat way using <b>f-strings</b>
#
# <p class = "alert alert-info" role="alert"><b>Remember</b> to format your input questions in a pedagogical way to guide the user
#
# The number of stars (\*), (\*\*), (\*\*\*) denotes the difficulty level of the task
#
# ---

# %% [markdown]
# ## 1. Find errors (*)
#
# Find the errors in this code to compute the distance between the point $(x,y)$ and the origin in a cartesian coordinate system.
#
# ```python
# impor numpy as np
#
# def distance(x,y)
#     reurn np.sqrt(x+y)
#
# print(distance([0.5, 0.5]))
#
# ```
#
# <details>
#
# <summary>Hint </summary>
#
# Also look for logical errors.
#
# </details>
# <br>
# <details>
#
# <summary>Answer </summary>
#
# ```
# The distance between (0.5, 0.5) and origin is around 0.707.
# ```
#
# </details>

# %%
import numpy as np

def distance(x,y):
    try:
        return np.sqrt(x**2+y**2)
    except Exception:
        print("You made a syntax error")

print(distance(0.5,0.5))
# Out:
# 0.7071067811865476

# %% [markdown]
# ---
# ## 2. Find errors (*)
#
# Find the errors in this code. Just change the function, don't touch the test program.
#
# ```python
#
# def is_fourdigit(number):
#     if number//1000 < 10
#         return true
#     else
#         return false
#
# # test program
# test_numbers = [231, 3124, -4124, -1000,-999, 1001, 10000, -10000, 999]
#
# for number in test_numbers:
#     if is_fourdigit(number):
#         print(f"{number} is four-digit")
#     else:
#         print(f"{number} is not four-digit")
#
# ```
#
# <details>
#
# <summary>Hint </summary>
#
# Print out and test different cases to build up the condition in the if-statement
#
# </details>
# <br>
# <details>
#
# <summary>Answer </summary>
#
# ```
#
# 231 is not four-digit
# 3124 is four-digit
# -4124 is four-digit
# -1000 is four-digit
# -999 is not four-digit
# 1001 is four-digit
# 10000 is not four-digit
# -10000 is not four-digit
# 999 is not four-digit
#
# ```
#
# </details>

# %%
def is_fourdigit(number):
    absolute_value = abs(number)
    if absolute_value//1000 < 1:
        return False
    else:
        return True

# Test program
test_numbers = [231, 3124, -4124, -1000,-999, 1001, 10000, -10000, 999]

for number in test_numbers:
    if is_fourdigit(number):
        print(f"{number} is four-digit")
    else:
        print(f"{number} is not four-digit")
# Out:
# 231 is not four-digit
# 3124 is four-digit
# -4124 is four-digit
# -1000 is four-digit
# -999 is not four-digit
# 1001 is four-digit
# 10000 is four-digit
# -10000 is four-digit
# 999 is not four-digit

# %% [markdown]
# ---
# ## 3. Tram (*)
#
# Kokchun is a **clumpsy** computer user that doesn't take trams too often. Write a program to prompt the user for:
# - number of times he/she wants to take tram in one month
# - cost for one ticket
# - cost for monthly card
#
# The program should calculate if it's worth for him to buy  monthly card or not. Make the program user friendly with clear error messages and ask again in case of input errors.
#
# <details>
#
# <summary>Hint </summary>
#
# Raise user friendly exceptions to guide the user to give right input format.
#
# </details>
# <br>
# <details>
#
# <summary>Answer </summary>
#
# For example:
#
# ```
# How many times do you take tram in one month? -23
# Number of times you take tram must be between 0 and 100
#
# How much does one ticket cost? (kr) 1000
# One ticket must cost between 0 and 100 kr
#
# How many times do you take tram in one month? 23
# How much does one ticket cost? (kr) 35
# How much does one month card cost? (kr) 600
#
# Cost with one-time tickets 805.0
# Cost with monthly card 600.0
# It's worth to buy a monthly card
#
# ```
#
# </details>

# %%
def get_integer_input(prompt):
    while True:
        try:
            value = int(input(prompt))
            return value
        except ValueError:
            print("Please enter a valid integer.")

def get_float_input(prompt):
    while True:
        try:
            value = float(input(prompt))
            return value
        except ValueError:
            print("Please enter a valid number.")

def main():
    print("Welcome to the Tram Fare Calculator!")

    # Get input from the user
    num_tram_rides = get_integer_input("Enter the number of tram rides per month: ")
    ticket_cost = get_float_input("Enter the cost of a single tram ticket: ")
    monthly_card_cost = get_float_input("Enter the cost of a monthly tram card: ")

    # Calculate the total cost for individual tickets and monthly card
    individual_cost = num_tram_rides * ticket_cost
    monthly_card_savings = individual_cost - monthly_card_cost

    # Check if it's worth buying a monthly card
    if monthly_card_savings < 0:
        print("It's not worth buying a monthly card. You will spend less on individual tickets.")
    else:
        print(f"It's worth buying a monthly card. You will save ${monthly_card_savings:.2f} per month.")

if __name__ == "__main__":
    main()


main()

# %%
def get_integer_input(prompt):
    while True:
        try:
            value = int(input(prompt))
            return value
        except ValueError:
            print("Please enter a valid integer.")

def get_float_input(prompt):
    while True:
        try:
            value = float(input(prompt))
            return value
        except ValueError:
            print("Please enter a valid number.")


def main():   # I en modul behöver man testa om koden funkar, detta med if satsen längst ned 
              # säkerställer att koden som ankallas här inte körs i de filer där man importerar modulen, så länge den är inom main om man specar detta.
    tram_rides = get_integer_input("Enter how many times you take the tram in one month: ")
    tram_unit_price = get_float_input("Enter how much a tram ticket cost: ")
    tram_monthly_price = get_float_input("Enter the price of a monthy tram ticker: ")


    total_price_units = tram_rides * tram_unit_price
    difference_prices = tram_monthly_price - total_price_units

    if difference_prices > 0:
        print(f"You will loose money on buying monthly tram tickets, keep buying unit tickets!")
    else: 
        print(f"You will save {abs(difference_prices)} by getting a monthly tram ticket!")

if __name__ == "__main__":
    main()
# Out:
# You will save 6.0 by getting a monthly tram ticket!

# %% [markdown]
# ---
#
# Kokchun Giang
#
# [LinkedIn][linkedIn_kokchun]
#
# [GitHub portfolio][github_portfolio]
#
# [linkedIn_kokchun]: https://www.linkedin.com/in/kokchungiang/
# [github_portfolio]: https://github.com/kokchun/Portfolio-Kokchun-Giang
#
# ---
